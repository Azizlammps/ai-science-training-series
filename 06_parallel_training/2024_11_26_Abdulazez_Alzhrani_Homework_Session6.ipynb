# %% [markdown]
# **HW#6**
#
# Submit proof that you were able to successfully follow the above instructions and launch a distributed data parallel training run.
#
# Where proof can be any of:
#
# The contents printed out to your terminal during the run
# A path to a logfile containing the output from a run on the ALCF filesystems
# A screenshot of:
# the text printed out from the run
# a graph from the W&B Run
# anything that shows that you clearly were able to run the example
# url to a W&B Run or W&B Report
# etc.

# %% [markdown]
# git clone https://github.com/saforem2/wordplay

# %% [markdown]
# ![Screen Shot 2024-11-26 at 21.01.05.png](data:image/png;base64,...)

# %% [markdown]
# git clone https://github.com/saforem2/ezpz deps/ezpz

# %% [markdown]
# ![Screen Shot 2024-11-26 at 21.02.53.png](data:image/png;base64,...)

# %% [markdown]
# export PBS_O_WORKDIR=$(pwd) && source deps/ezpz/src/ezpz/bin/utils.sh

# %% [markdown]
# ![Screen Shot 2024-11-26 at 21.03.33.png](data:image/png;base64,...)

# %% [markdown]
# ezpz_setup_python

# %% [markdown]
# ![Screen Shot 2024-11-26 at 21.04.30.png](data:image/png;base64,...)

# %% [markdown]
# python3 -m pip install -e deps/ezpz --require-virtualenv

# %% [markdown]
# ![Screen Shot 2024-11-26 at 21.06.48.png](data:image/png;base64,...)

# %% [markdown]
# python3 -m pip install -e . --require-virtualenv

# %% [markdown]
# ![Screen Shot 2024-11-26 at 21.07.39.png](data:image/png;base64,...)

# %% [markdown]
# I prepared a PBS script (pbs.sh) to submit the job via the scheduler. The script allocates 16 CPUs, 8 MPI processes, 2 threads per process, and 16GB memory. It sets up the environment and runs the ezpz.test_dist script with mpirun.

# %% [markdown]
# !/bin/bash
# PBS -N ezpz_test_dist
#
# PBS -l select=1:ncpus=16:mpiprocs=8:ompthreads=2:mem=16GB
# PBS -m bea
#
# PBS -l walltime=01:00:00
#
# PBS -j oe
#
# PBS -o ${PBS_JOBNAME}.out
#
#
# cd $PBS_O_WORKDIR
#
# echo "Working on directory: $PWD"
#
# echo "Loaded modules:"
#
# module list
#
# echo "Python version:"
#
# python3 --version
#
# echo "Running ezpz.test_dist with mpirun..."
#
# mpirun -np 8 python3 -m ezpz.test_dist

# %% [markdown]
# #Some Results

# %% [markdown]
# ![Screen Shot 2024-11-26 at 21.15.32.png](data:image/png;base64,...)![Screen Shot 2024-11-26 at 21.16.05.png](data:image/png;base64,...)![Screen Shot 2024-11-26 at 21.16.18.png](data:image/png;base64,...)![Screen Shot 2024-11-26 at 21.16.29.png](data:image/png;base64,...)![Screen Shot 2024-11-26 at 21.16.50.png](data:image/png;base64,...)![Screen Shot 2024-11-26 at 21.17.02.png](data:image/png;base64,...)
